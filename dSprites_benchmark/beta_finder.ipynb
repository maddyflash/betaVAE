# %%
# %matplotlib inline
# %tensorflow_version 2.x

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import tensorflow as tf
import numpy as np
import math
import typing
import tqdm
import os
import itertools
import copy
import subprocess

from pathlib import Path
from enum import IntEnum
from sklearn.decomposition import FastICA

np.random.seed(42)
tf.random.set_seed(231)
# template name
model_name = "vae{}_weights_100e_550ktr.h5"
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# # Build a model according to specification (Tbl. 1 Higgins et al.)
# * **Input**  4096 (flattened 64x64x1).
# * **Encoder**  FC 1200, 1200. ReLU activation.
# * **Latents**  10
# * **Decoder**  FC 1200, 1200, 1200, 4096. Tanh activation. Bernoulli.
# * **Optimiser** Adagrad 1e-2

# %%
class VAE(tf.keras.Model):
    def __init__(self, latent_dim=10):
        super(VAE, self).__init__()
        self._latent_dim = latent_dim
        self.encoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer((64, 64, 1)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(1200, activation='relu'),
            tf.keras.layers.Dense(1200, activation='relu'),
            tf.keras.layers.Dense(latent_dim * 2)
        ])
        self.decoder = tf.keras.Sequential([
            tf.keras.layers.InputLayer(latent_dim),
            tf.keras.layers.Dense(1200, activation='tanh'),
            tf.keras.layers.Dense(1200, activation='tanh'),
            tf.keras.layers.Dense(1200, activation='tanh'),
            tf.keras.layers.Dense(4096),
            tf.keras.layers.Reshape((64, 64, 1))
        ])

    def call(self, x): raise NotImplementedError

    def encode(self, x):
        h = self.encoder(x)
        mean, logvar = tf.split(h, num_or_size_splits=2, axis=1)
        return self.reparameterise(mean, logvar), mean, logvar
    
    def decode(self, z):
        return self.decoder(z)

    @staticmethod
    def reparameterise(mean, logvar):
        # log sig^2 = 2 log sig => exp(1/2 log sig^2) = exp(log sig) = sig
        eps = tf.random.normal(mean.shape, mean=0.0, stddev=1.0)
        return mean + tf.exp(logvar * 0.5) * eps

BETA = 4
EPOCHS = 100
LATENT_DIM = 10
BATCH_SIZE = 32
TR_SIZE = 550_000

# %%
class PCA:
    def __init__(self, latent_dim: int, ds: 'DSprites', subset: int=100_000):
        x = ds.subset(subset)
        self._width = x.shape[1]
        self._height = x.shape[2]
        self.mean = np.mean(x, axis=0)
        self._latent_dim = latent_dim
        self._D = self._width * self._height
        x = (x - self.mean).reshape(-1, self._D)
        self._e, V = tf.linalg.eigh(tf.matmul(x.T, x))
        assert V.shape == (self._D, self._D)
        # non-decreasing => take the last latent_dim cols!
        self.V_k = V[:, -self._latent_dim:]
    
    def encode(self, x):
        x = (x - self.mean).reshape(-1, self._D)
        z = tf.matmul(x, self.V_k)
        assert z.shape == (x.shape[0], self._latent_dim)
        # our VAE encoders return z, mean, logvar
        # and our data generator takes the mean (see generate_benchmarking_dataset)
        # so we have to return z in the middle of a 3-tuple
        return z, z, None
    
    def decode(self, z):
        return tf.matmul(z, self.V_k, transpose_b=True).numpy().reshape(-1, self._width, self._height, 1) # + self.mean

    @property
    def explained_variance_ratio(self):
        e = self._e.numpy()[::-1]       
        return e[: self._latent_dim]/sum(e)

class ICA:
    def __init__(self, latent_dim: int, ds: 'DSprites', subset: int=100_000):
        x = ds.subset(subset)
        self._width = x.shape[1]
        self._height = x.shape[2]
        self._D = self._width * self._height
        self._model = FastICA(n_components=latent_dim)
        self._model.fit(x.reshape(-1, self._D))

    def encode(self, x):
        z = self._model.transform(x.reshape(-1, self._D))
        return z, z, None

    def decode(self, z):
        return self._model.inverse_transform(z).reshape(-1, self._width, self._height, 1)

# %%
class DSprites:
    class Latents(IntEnum):
        COLOUR, SHAPE, SCALE, ORIENTATION, XPOS, YPOS = range(6)
        
    """
    A significant portion of this class is taken as-is from the manual
    https://github.com/deepmind/dsprites-dataset/blob/master/dsprites_reloading_example.ipynb
    """
    def __init__(self, path=".", download=False):
        self._filename = 'dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz'
        path = Path(path).absolute()
        assert path.exists()
        data = path / self._filename
        if not data.exists():
            if download:
                subprocess.run(["wget", "-O", str(data),
                                "https://github.com/deepmind/dsprites-dataset/raw/master/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz"])
            else:
                raise ValueException("Can't find dataset, use download=True to download.")
        data = np.load(str(data), encoding='bytes', allow_pickle=True)

        # ====

        imgs = data['imgs']
        metadata_raw = data['metadata'][()]
        self._metadata = dict()
        for k, v in metadata_raw.items():
            self._metadata[k.decode()] = v

        # NOTE: can't cast now because our notebook runs out of RAM. cast in map instead
        # imgs = imgs.reshape(-1, 64, 64, 1).astype(np.float32)
        self._imgs = imgs.reshape(-1, 64, 64, 1)

        # for example: array([ 0,  0,  2, 37, 15, 22])
        # i.e. the relative (normalised) change in latent factors
        self._latents_classes = data['latents_classes']

        # for example: array([1., 1., 0.7 , 5.96097068, 0.48387097, 0.70967742])
        # i.e. the actual latent values used to generate the image
        self._latents_values = data['latents_values']

        # specification: the number of varying "degrees" of change in each
        # dimension corresponding to an independent generative factor
        # array([ 1,        3,      6,           40,  32,  32])
        #       colour, shape,  scale,  orientation,   X,   Y
        self._latents_sizes = self._metadata['latents_sizes']

        # for easy conversion from latent vector to indices later (see latent_to_idx)
        # essentially: array([737280, 245760,  40960,   1024,     32,      1])
        self._latents_bases = np.r_[self._latents_sizes[::-1].cumprod()[::-1][1:], 1]
    
    def latent_size(self, latent: 'DSprites.Latents') -> int:
        """
        :param latent: of type DSprites.Latents (an enum class)
        :return: the maximum integer allowed for the specified `latent`
        """
        return self._latents_sizes[latent.value]
    
    def to_idx(self, latents: np.array) -> int:
        """
        convert latent vector into index that can then be used to index
        the actual image in self._imgs
        """
        return np.dot(latents, self._latents_bases).astype(int)
    
    def sample_latent(self, n: int=1, fixed: 'DSprites.Latents'=None) -> np.array:
        """
        randomly samples `n` latent vectors

        :param n: number samples
        :param fixed: if not `None`, then in all samples, this latent is kept
                     fixed based on a random draw. The rest of the latents are
                     random.
        :return: an `np.array` of shape nx6
        """
        samples = np.zeros((n, self._latents_sizes.shape[0]))
        for i, lat_size in enumerate(self._latents_sizes):
            samples[:, i] = np.random.randint(lat_size, size=n)
        if fixed:
            samples[:, fixed] = np.random.randint(0, ds.latent_size(fixed))
        return samples
    
    @property
    def imgs(self) -> np.array:
        return self._imgs

    def subset(self, size=50_000) -> np.array:
        """
        returns a subset of the images. (Workaround for memory constraints)
        :param size: number of samples to return
        """
        return self._imgs[np.random.choice(self._imgs.shape[0], size=size, replace=False)]

def make_grid(tensor: np.array, nrow: int=8, padding: int=2, pad_value: int=0) -> np.array:
    """
    adapted from: https://pytorch.org/docs/stable/_modules/torchvision/utils.html#make_grid
    :param tensor: nxwxhxc np.array
    :param nrow: number of images displayed in each row
    :param padding: padding between images
    :param pad_value: value used to pad
    :return: np.array of dimension 3 (WxHxC) with all images arranged in a grid.

    """
    if tensor.shape[0] == 1:
        return tensor.squeeze()

    # make the mini-batch of images into a grid
    nmaps = tensor.shape[0]
    xmaps = min(nrow, nmaps)
    ymaps = int(math.ceil(float(nmaps) / xmaps))
    height, width = int(tensor.shape[1] + padding), int(tensor.shape[2] + padding)
    num_channels = tensor.shape[3]
    grid = np.full((height * ymaps + padding, width * xmaps + padding, num_channels), pad_value, dtype=tensor.dtype)
    k = 0
    for y in range(ymaps):
        for x in range(xmaps):
            if k >= nmaps: break
            ystart = y * height + padding
            xstart = x * width + padding
            grid[ystart:(ystart + height - padding), ...][:, xstart:(xstart + width - padding), :] = tensor[k]
            k = k + 1
    return grid.squeeze()

def imshow(img: np.array, title: str='', ax: plt.Axes=None):
    if not ax:
        fig = plt.figure(figsize=(15, 15))
        ax = fig.add_subplot(111)
    ax.imshow(img, cmap='gray', interpolation='nearest')
    ax.set_xticks(())
    ax.set_yticks(())
    if title:
        ax.set_title(title)

# %%
ds = DSprites(download=True)
test_batch = ds.subset(size=32)
imshow(make_grid(test_batch))

# %%
# pca = PCA(LATENT_DIM, ds, subset=75_000)
# print(pca.explained_variance_ratio)
# print(sum(pca.explained_variance_ratio))

# # simple sanity check
# z, *_ = pca.encode(test_batch)
# fig = plt.figure(figsize=(15, 15))
# ax1 = fig.add_subplot(121)
# ax2 = fig.add_subplot(122)
# imshow(make_grid(test_batch), title='Original', ax=ax1)
# imshow(make_grid(pca.decode(z)), title='Reconstructed', ax=ax2)
# fig.subplots_adjust(wspace=0.01)
# plt.show()

# %%
vae05 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae05.load_weights(model_name.format("0.5"))

# simple sanity check
z, *_ = vae05.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae05.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae1 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae1.load_weights(model_name.format(1))

# simple sanity check
z, *_ = vae1.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae1.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae2 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae2.load_weights(model_name.format(2))

# simple sanity check
z, *_ = vae2.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae2.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae3 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae3.load_weights(model_name.format(3))

# simple sanity check
z, *_ = vae3.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae3.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae4 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae4.load_weights(model_name.format(4))

z, *_ = vae4.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae4.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae5 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae5.load_weights(model_name.format(5))

# simple sanity check
z, *_ = vae5.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae5.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae6 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae6.load_weights(model_name.format(6))

# simple sanity check
z, *_ = vae6.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae6.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae7 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae7.load_weights(model_name.format(7))

# simple sanity check
z, *_ = vae7.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae7.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae8 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae8.load_weights(model_name.format(8))

# simple sanity check
z, *_ = vae8.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae8.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae9 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae9.load_weights(model_name.format(9))

# simple sanity check
z, *_ = vae9.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae9.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
vae10 = VAE(LATENT_DIM)
# load pretrained model with 100 epochs (from 550k randomly sampled points)
vae10.load_weights(model_name.format(10))

# simple sanity check
z, *_ = vae10.encode(test_batch)
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imshow(make_grid(test_batch), title='Original', ax=ax1)
imshow(make_grid(tf.nn.sigmoid(vae10.decode(z)).numpy()), title='Reconstructed', ax=ax2)
fig.subplots_adjust(wspace=0.01)
plt.show()

# %%
# vae_untrained = VAE(LATENT_DIM)

# z, *_ = vae_untrained.encode(test_batch)
# fig = plt.figure(figsize=(15, 15))
# ax1 = fig.add_subplot(121)
# ax2 = fig.add_subplot(122)
# imshow(make_grid(test_batch), title='Original', ax=ax1)
# imshow(make_grid(tf.nn.sigmoid(vae_untrained.decode(z)).numpy()), title='Reconstructed', ax=ax2)
# fig.subplots_adjust(wspace=0.01)
# plt.show()

# %% [markdown]
# # Generating $z^b_{diff}$
#
# for batch $b$ = 1 ... B:
#    1. sample $y_b$ from Unif(SCALE, XPOS, YPOS, ORIENTATION)
#    2. repeat L times to get $z^{l=1}_{diff}$, $\dots$, $z^{l=L}_{diff}$:
#
#         (a) sample latents vectors $v_{1, l}$ and $v_{2, l}$ where the value in the dimension corresponding to $y_b$ is kept fixed.
#
#         (b) generate images $x_{1, l}$ and $x_{2, l}$ from $Sim(v_{1, l})$ and $Sim(v_{2, l})$
#
#         (c) calculate $z_{1, l} = \mu(x_{1, l})$ where $\mu(.)$ is the (neural network) encoder portion that is responsible for outputting the mean of the posterior $q_\phi(\mathbf z| \mathbf x) = \mathcal N\left(\mathbf z; \mu(\mathbf x), \Sigma(\mathbf x)\right)$; likewise $z_{2,l} = \mu(x_{2, l})$
#
#         (d) finally, calculate $z^l_{diff} = |z_{1, 1} - z_{2,l}|$
#
# 3. we obtain $z^b_{diff} = \frac{1}{L}\sum_l^L z^l_{diff}$
#
# The `generate_benchmarking_dataset` function then returns $z^{b=1}_{diff}, \dots, z^{b=B}_{diff}$  and their corresponding fixed latents $y_b$.
#
# > Note that **colour** and **shape** are not evaluated. **Colour** is understandable as all
# images are white, however, **shape** is conspicously left out, perhaps because the paper (and in our reproduced result) shows that none of the learnt latents encode **shape**.

# %%
def generate_benchmarking_dataset(model: VAE,
                                  ds: DSprites, l: int,
                                  batches: int,
                                  with_shapes: bool=False) -> typing.Tuple[np.array, np.array]:
    """
    :param model: must have an `encode` function that takes a tensor of shape
                  N x W x H x C and returns a tuple (z, mean, logvar)
                  where all three elements are of shape N x LATENT_DIM
    :param ds: DSprites dataset                 
    :param l: number of samples to draw for a given fixed latent. Corresponds
              to the same L described in the paper.
    :param batches: number of batches. Corresponds to the same B
                    described in the paper.
    :param with_shapes: should shapes be included as a fixed latent or ignored?
                        By default it is ignored as the paper did too.
    :return: a tuple of x and y where x is an array of shape  b x LATENT_DIM
             and y is an array of length b. That is, x[b] = z^b_diff.
    """                                
    x = []
    y = []
    # here, each batch is allowed to fix a different latent factor
    for b in tqdm.trange(batches):
        # low=2 because 0 is COLOUR which is always fixed and 1 is SHAPE
        # but the paper doesn't evaluate SHAPEs
        least_latent_idx = 1 if with_shapes else 2
        y_fixed = DSprites.Latents(
            np.random.randint(low=least_latent_idx, high=6, size=1)
        )
        assert y_fixed != DSprites.Latents.COLOUR and (with_shapes or y_fixed != DSprites.Latents.SHAPE)

        # 2*l x LATENT_DIM: 2*l because for each l we take the difference of 2 Zs
        _, mean, _ = model.encode(
            ds.imgs[ds.to_idx(ds.sample_latent(n=(2 * l), fixed=y_fixed))]
        )

        # z_{1,l} = mean(x_{1,l}); z_{2,l} = mean(x_{2,l})
        # z^b_diff = average_l(z^l_diff) where z^l_diff = |z_{1,l} - z_{2,l}|

        zldiff = np.array([tf.abs(mean[i] - mean[i + 1]).numpy() for i in range(0, 2 * l, 2)])
        assert zldiff.shape == (l, mean.shape[1])
        zbdiff = np.mean(zldiff, axis=0)
        assert zbdiff.shape == (mean.shape[1], )
        x.append(zbdiff)
        assert y_fixed.value >= least_latent_idx
        # the integers are expected to start from 0 but we start from low=least_latent_idx
        # hence, we have to shift it.
        y.append(y_fixed.value - least_latent_idx)
    return np.array(x), np.array(y)

# %% [markdown]
# # Quantitative measure: Linear classifer
#
# From Higgins et al. (2017):
# > We used a fully connected linear classifier to predict $p(y|\mathbf z^b_{diff})$, where y is one of four generative factors (position X, position Y, scale
# and rotation). We used softmax output nonlinearity and a negative log likelihood loss function. The classifier was trained using the Adagrad (Duchi et al., 2011) optimisation algorithm with learning rate of 1e-2 until convergence.
#
# The code below is an exact translation of the excerpt above.

# %%
def get_linear_classifier(num_classes=4) -> tf.keras.Model:
    """
    :param num_classes: number of output classes. By default, there are
                        four: XPOS, YPOS, SCALE, ORIENTATION/ROTATION.
    :return: keras model. A linear classifier that's essentially a multiclass
             logistic regression.
    """
    model = tf.keras.Sequential([
       tf.keras.layers.InputLayer((LATENT_DIM,)),
       tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=1e-2),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['accuracy'])
    return model
get_linear_classifier().summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_77 (Dense)             (None, 4)                 44
# =================================================================
# Total params: 44
# Trainable params: 44
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluating the models
#
# In this experiement, we'll reproduce the results for $\beta$-vae, regular vae, and PCA. From the paper, it states that
# "[t]en replicas of each model with the same hyperparameters were trained using different random seeds to obtain disentangled representations. Each of the ten trained model replicas was evaluated three times using the disentanglement metric score algorithm, each time using a different random seed to initialise the linear classifier. We then discarded the bottom 50% of the thirty resulting scores and reported the remaining results. This was done to control for the outlier results from the few experiments that diverged during training.".
#
# In summary, there are ten independent copies of each model each trained separately (different seeds used for weight initializations) but identically. Next, each of the ten models are evaulated thrice using the linear classifier and the bottom 50% of the thirty resulting scores are discarded.
#
# Here, instead of having ten independent copies of the models, we'll have one each but evaluated three times using the linear classifier. Therefore, instead of thirty scores per model, we will only have three. *Arguably, as long as our results do not diverge, a single model should suffice.*
#
# Later, we will also evaluate the models **with** shape included as the fixed generative factor to see how it affects the metric, despite none of the $z_i$s showing that it identified shape as an independent latent.

# %%
# how many times to repeat the experiment. Each repetition creates a
# new linear classifier with different initial values
REPEAT = 3
# in each batch, we take the average of L zdiffs
L = 64
# take B batches, i.e. creating a dataset of size (B, LATENT_DIM)
B = 10_000
# section 4.2: The table in Fig. 6 (left) reports the classification accuracy of the disentanglement metric for 5,000 test samples
E = 5_000

# %%
def run_experiment(model: VAE, ds: DSprites, l: int, batches: int, test_batch: int,
                   reps: int, with_shapes: bool=False, verbose: int=1) -> np.array:
    """
    :param model: must have an `encode` function that takes a tensor of shape
                  N x W x H x C and returns a tuple (z, mean, logvar)
                  where all three elements are of shape N x LATENT_DIM
    :param ds: DSprites object used to generate dataset                 
    :param l: number of samples to draw for a given fixed latent. Corresponds
              to the same L described in the paper.
    :param batches: number of batches. Corresponds to the same B
                    described in the paper.
    :param test_batch: number of test batch. The paper used 5,000 test points
                       to evulate the accuracy of the linear classifier.                   
    :param reps: number of times to repeat this experiment.
    :param with_shapes: should shapes be included as a latent factor that should
                        be measured?
    :param verbose: verbosity level of model.fit(..., verbose) where model
                    is of type `tf.keras.Model`.
    :return: an np.array of accuracies. This array is of length `reps`, where
             each element corresponds to the maximum accuracy
             obtained during training for that particular iteration.
    """
    # create data (z^b_diff)s
    x_train, y_train = generate_benchmarking_dataset(model, ds,
                                                     l=l, batches=(batches + test_batch),
                                                     with_shapes=with_shapes)
    x_train = x_train[: batches]
    y_train = y_train[: batches]
    x_test = x_train[-test_batch:]
    y_test = y_train[-test_batch:]

    assert x_train.shape == (B, LATENT_DIM) and y_train.shape == (B, )
    assert x_test.shape == (E, LATENT_DIM) and y_test.shape == (E, )
    assert ((y_train < (5 if with_shapes else 4)) & (y_train >= 0)).all()
    assert ((y_test < (5 if with_shapes else 4)) & (y_test >= 0)).all()
    
    # show target class distribution
    counts = dict(zip(*np.unique(y_train, return_counts=True)))
    plt.bar([DSprites.Latents(k + (1 if with_shapes else 2)).name for k in counts.keys()], counts.values())
    plt.title(f"Distribution of fixed latents in {B:,} samples.")
    print(counts)

    accuracies = []
    for r in range(1, reps + 1):
        print(f"\n\n==========\nExperiment {r}")
        linear_classifier = get_linear_classifier(num_classes=(5 if with_shapes else 4))
        # use this callback as a monitor - use an absurd number of epochs and stop
        # only when the accuracy doesn't improve
        until_convergence = tf.keras.callbacks.EarlyStopping(monitor='accuracy',
                                                             min_delta=1e-5,
                                                             patience=10)          
        history = linear_classifier.fit(x_train, y_train,
                                      batch_size=32, epochs=500,
                                      callbacks=[until_convergence],
                                      verbose=verbose)
        accuracies.append(linear_classifier.evaluate(x_test, y_test)[-1])
        
    return np.array(accuracies)

# %%
accs = []
for vae in [vae05, vae1, vae2, vae3, vae4, vae5, vae6, vae7, vae8, vae9, vae10]:
    accs.append(run_experiment(vae, ds, l=L, batches=B, test_batch=E, reps=REPEAT, with_shapes=False))

# 11x3 matrix
accs = np.array(accs)
print(np.mean(accs, axis=1))
print(np.std(accs, axis=1))
# Out:
# 100%|██████████| 15000/15000 [07:58<00:00, 31.37it/s]
# {0: 2550, 1: 2416, 2: 2522, 3: 2512}
#
#
# ==========
# Experiment 1
# Train on 10000 samples
# Epoch 1/500
# 10000/10000 [==============================] - 1s 99us/sample - loss: 1.3512 - accuracy: 0.2992
# Epoch 2/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.3067 - accuracy: 0.4385
# Epoch 3/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2947 - accuracy: 0.4959
# Epoch 4/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2849 - accuracy: 0.5138
# Epoch 5/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2767 - accuracy: 0.5247
# Epoch 6/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2693 - accuracy: 0.5417
# Epoch 7/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2628 - accuracy: 0.5498
# Epoch 8/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.2568 - accuracy: 0.5519
# Epoch 9/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2512 - accuracy: 0.5593
# Epoch 10/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2462 - accuracy: 0.5569
# Epoch 11/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2413 - accuracy: 0.5636
# Epoch 12/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.2368 - accuracy: 0.5668
# Epoch 13/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2326 - accuracy: 0.5715
# Epoch 14/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.2285 - accuracy: 0.5708
# Epoch 15/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2247 - accuracy: 0.5725
# Epoch 16/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2210 - accuracy: 0.5698
# Epoch 17/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2175 - accuracy: 0.5740
# Epoch 18/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.2141 - accuracy: 0.5737
# Epoch 19/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.2109 - accuracy: 0.5757
# Epoch 20/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2078 - accuracy: 0.5754
# Epoch 21/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2048 - accuracy: 0.5767
# Epoch 22/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.2019 - accuracy: 0.5778
# Epoch 23/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1991 - accuracy: 0.5783
# Epoch 24/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1964 - accuracy: 0.5801
# Epoch 25/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1937 - accuracy: 0.5781
# Epoch 26/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1912 - accuracy: 0.5774
# Epoch 27/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1887 - accuracy: 0.5810
# Epoch 28/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1863 - accuracy: 0.5778
# Epoch 29/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1840 - accuracy: 0.5819
# Epoch 30/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1817 - accuracy: 0.5797
# Epoch 31/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1795 - accuracy: 0.5812
# Epoch 32/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1773 - accuracy: 0.5805
# Epoch 33/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1752 - accuracy: 0.5794
# Epoch 34/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1731 - accuracy: 0.5801
# Epoch 35/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1711 - accuracy: 0.5823
# Epoch 36/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1691 - accuracy: 0.5790
# Epoch 37/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1672 - accuracy: 0.5802
# Epoch 38/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1653 - accuracy: 0.5803
# Epoch 39/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1634 - accuracy: 0.5811
# Epoch 40/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1616 - accuracy: 0.5812
# Epoch 41/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1598 - accuracy: 0.5815
# Epoch 42/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1581 - accuracy: 0.5831
# Epoch 43/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1564 - accuracy: 0.5820
# Epoch 44/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1547 - accuracy: 0.5813
# Epoch 45/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1530 - accuracy: 0.5825
# Epoch 46/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1514 - accuracy: 0.5817
# Epoch 47/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1498 - accuracy: 0.5823
# Epoch 48/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1483 - accuracy: 0.5832
# Epoch 49/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1467 - accuracy: 0.5836
# Epoch 50/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1452 - accuracy: 0.5827
# Epoch 51/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1437 - accuracy: 0.5818
# Epoch 52/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1423 - accuracy: 0.5824
# Epoch 53/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1408 - accuracy: 0.5860
# Epoch 54/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1394 - accuracy: 0.5839
# Epoch 55/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1380 - accuracy: 0.5825
# Epoch 56/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1367 - accuracy: 0.5836
# Epoch 57/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1353 - accuracy: 0.5840
# Epoch 58/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1340 - accuracy: 0.5849
# Epoch 59/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1327 - accuracy: 0.5826
# Epoch 60/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1314 - accuracy: 0.5829
# Epoch 61/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1301 - accuracy: 0.5842
# Epoch 62/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1288 - accuracy: 0.5843
# Epoch 63/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1276 - accuracy: 0.5843
# 5000/5000 [==============================] - 0s 64us/sample - loss: 1.1263 - accuracy: 0.5866
#
#
# ==========
# Experiment 2
# Train on 10000 samples
# Epoch 1/500
# 10000/10000 [==============================] - 1s 85us/sample - loss: 1.4154 - accuracy: 0.3305
# Epoch 2/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.3579 - accuracy: 0.3500
# Epoch 3/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.3465 - accuracy: 0.3538
# Epoch 4/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.3368 - accuracy: 0.3666
# Epoch 5/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.3287 - accuracy: 0.3669
# Epoch 6/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.3213 - accuracy: 0.3829
# Epoch 7/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.3146 - accuracy: 0.3896
# Epoch 8/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.3085 - accuracy: 0.3906
# Epoch 9/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.3027 - accuracy: 0.4023
# Epoch 10/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2974 - accuracy: 0.4047
# Epoch 11/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.2924 - accuracy: 0.4064
# Epoch 12/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2877 - accuracy: 0.4146
# Epoch 13/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.2832 - accuracy: 0.4178
# Epoch 14/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2790 - accuracy: 0.4216
# Epoch 15/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2749 - accuracy: 0.4229
# Epoch 16/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2710 - accuracy: 0.4281
# Epoch 17/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.2673 - accuracy: 0.4304
# Epoch 18/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2637 - accuracy: 0.4374
# Epoch 19/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2603 - accuracy: 0.4389
# Epoch 20/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2570 - accuracy: 0.4403
# Epoch 21/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2538 - accuracy: 0.4418
# Epoch 22/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2507 - accuracy: 0.4472
# Epoch 23/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.2476 - accuracy: 0.4531
# Epoch 24/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2448 - accuracy: 0.4502
# Epoch 25/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2419 - accuracy: 0.4549
# Epoch 26/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.2392 - accuracy: 0.4592
# Epoch 27/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.2365 - accuracy: 0.4597
# Epoch 28/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2339 - accuracy: 0.4624
# Epoch 29/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2314 - accuracy: 0.4647
# Epoch 30/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2289 - accuracy: 0.4664
# Epoch 31/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2265 - accuracy: 0.4701
# Epoch 32/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2242 - accuracy: 0.4703
# Epoch 33/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.2219 - accuracy: 0.4717
# Epoch 34/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.2196 - accuracy: 0.4733
# Epoch 35/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2174 - accuracy: 0.4767
# Epoch 36/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2153 - accuracy: 0.4786
# Epoch 37/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.2132 - accuracy: 0.4780
# Epoch 38/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2111 - accuracy: 0.4807
# Epoch 39/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.2091 - accuracy: 0.4846
# Epoch 40/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.2071 - accuracy: 0.4836
# Epoch 41/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.2052 - accuracy: 0.4867
# Epoch 42/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.2033 - accuracy: 0.4867
# Epoch 43/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2014 - accuracy: 0.4878
# Epoch 44/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1996 - accuracy: 0.4902
# Epoch 45/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1978 - accuracy: 0.4891
# Epoch 46/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1960 - accuracy: 0.4929
# Epoch 47/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1942 - accuracy: 0.4915
# Epoch 48/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1925 - accuracy: 0.4927
# Epoch 49/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1908 - accuracy: 0.4951
# Epoch 50/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1892 - accuracy: 0.4948
# Epoch 51/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1876 - accuracy: 0.4984
# Epoch 52/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.1860 - accuracy: 0.4983
# Epoch 53/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1844 - accuracy: 0.4984
# Epoch 54/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1828 - accuracy: 0.5001
# Epoch 55/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1813 - accuracy: 0.5007
# Epoch 56/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1798 - accuracy: 0.5011
# Epoch 57/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.1783 - accuracy: 0.5029
# Epoch 58/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1768 - accuracy: 0.5026
# Epoch 59/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1754 - accuracy: 0.5049
# Epoch 60/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1740 - accuracy: 0.5068
# Epoch 61/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1725 - accuracy: 0.5089
# Epoch 62/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1712 - accuracy: 0.5076
# Epoch 63/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1698 - accuracy: 0.5101
# Epoch 64/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1684 - accuracy: 0.5081
# Epoch 65/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1671 - accuracy: 0.5119
# Epoch 66/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1658 - accuracy: 0.5115
# Epoch 67/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1645 - accuracy: 0.5132
# Epoch 68/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.1632 - accuracy: 0.5133
# Epoch 69/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1619 - accuracy: 0.5151
# Epoch 70/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1607 - accuracy: 0.5154
# Epoch 71/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1594 - accuracy: 0.5151
# Epoch 72/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1582 - accuracy: 0.5167
# Epoch 73/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1570 - accuracy: 0.5176
# Epoch 74/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1558 - accuracy: 0.5186
# Epoch 75/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1546 - accuracy: 0.5178
# Epoch 76/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1535 - accuracy: 0.5199
# Epoch 77/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1523 - accuracy: 0.5198
# Epoch 78/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1512 - accuracy: 0.5190
# Epoch 79/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1501 - accuracy: 0.5210
# Epoch 80/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1489 - accuracy: 0.5223
# Epoch 81/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1478 - accuracy: 0.5226
# Epoch 82/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1467 - accuracy: 0.5226
# Epoch 83/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1457 - accuracy: 0.5235
# Epoch 84/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1446 - accuracy: 0.5227
# Epoch 85/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1435 - accuracy: 0.5245
# Epoch 86/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1425 - accuracy: 0.5235
# Epoch 87/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1415 - accuracy: 0.5252
# Epoch 88/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1404 - accuracy: 0.5260
# Epoch 89/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1394 - accuracy: 0.5257
# Epoch 90/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1384 - accuracy: 0.5267
# Epoch 91/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1374 - accuracy: 0.5267
# Epoch 92/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1364 - accuracy: 0.5291
# Epoch 93/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1354 - accuracy: 0.5293
# Epoch 94/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1345 - accuracy: 0.5290
# Epoch 95/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1335 - accuracy: 0.5296
# Epoch 96/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1326 - accuracy: 0.5309
# Epoch 97/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1316 - accuracy: 0.5303
# Epoch 98/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1307 - accuracy: 0.5315
# Epoch 99/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1298 - accuracy: 0.5313
# Epoch 100/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1289 - accuracy: 0.5312
# Epoch 101/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1280 - accuracy: 0.5324
# Epoch 102/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1271 - accuracy: 0.5325
# Epoch 103/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1262 - accuracy: 0.5335
# Epoch 104/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1253 - accuracy: 0.5332
# Epoch 105/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1244 - accuracy: 0.5345
# Epoch 106/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1235 - accuracy: 0.5354
# Epoch 107/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1227 - accuracy: 0.5340
# Epoch 108/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1218 - accuracy: 0.5360
# Epoch 109/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1210 - accuracy: 0.5369
# Epoch 110/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1201 - accuracy: 0.5369
# Epoch 111/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1193 - accuracy: 0.5370
# Epoch 112/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1185 - accuracy: 0.5379
# Epoch 113/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1177 - accuracy: 0.5383
# Epoch 114/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1169 - accuracy: 0.5401
# Epoch 115/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1160 - accuracy: 0.5387
# Epoch 116/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1152 - accuracy: 0.5392
# Epoch 117/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1145 - accuracy: 0.5411
# Epoch 118/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1137 - accuracy: 0.5406
# Epoch 119/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1129 - accuracy: 0.5402
# Epoch 120/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1121 - accuracy: 0.5418
# Epoch 121/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1113 - accuracy: 0.5409
# Epoch 122/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1106 - accuracy: 0.5418
# Epoch 123/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1098 - accuracy: 0.5431
# Epoch 124/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1091 - accuracy: 0.5438
# Epoch 125/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.1083 - accuracy: 0.5430
# Epoch 126/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.1076 - accuracy: 0.5435
# Epoch 127/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1069 - accuracy: 0.5440
# Epoch 128/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1061 - accuracy: 0.5454
# Epoch 129/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1054 - accuracy: 0.5454
# Epoch 130/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.1047 - accuracy: 0.5459
# Epoch 131/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1040 - accuracy: 0.5446
# Epoch 132/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.1033 - accuracy: 0.5455
# Epoch 133/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.1026 - accuracy: 0.5461
# Epoch 134/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1019 - accuracy: 0.5459
# Epoch 135/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.1012 - accuracy: 0.5463
# Epoch 136/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1005 - accuracy: 0.5462
# Epoch 137/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0998 - accuracy: 0.5462
# Epoch 138/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0991 - accuracy: 0.5470
# Epoch 139/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0984 - accuracy: 0.5467
# Epoch 140/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0978 - accuracy: 0.5477
# Epoch 141/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0971 - accuracy: 0.5469
# Epoch 142/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0965 - accuracy: 0.5478
# Epoch 143/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0958 - accuracy: 0.5473
# Epoch 144/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0952 - accuracy: 0.5477
# Epoch 145/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0945 - accuracy: 0.5489
# Epoch 146/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0939 - accuracy: 0.5483
# Epoch 147/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0932 - accuracy: 0.5486
# Epoch 148/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0926 - accuracy: 0.5488
# Epoch 149/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0920 - accuracy: 0.5490
# Epoch 150/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0913 - accuracy: 0.5496
# Epoch 151/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0907 - accuracy: 0.5503
# Epoch 152/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0901 - accuracy: 0.5506
# Epoch 153/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0895 - accuracy: 0.5499
# Epoch 154/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0889 - accuracy: 0.5510
# Epoch 155/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0883 - accuracy: 0.5509
# Epoch 156/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0877 - accuracy: 0.5519
# Epoch 157/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0871 - accuracy: 0.5500
# Epoch 158/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0865 - accuracy: 0.5511
# Epoch 159/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0859 - accuracy: 0.5517
# Epoch 160/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0853 - accuracy: 0.5521
# Epoch 161/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0847 - accuracy: 0.5521
# Epoch 162/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0841 - accuracy: 0.5534
# Epoch 163/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0835 - accuracy: 0.5525
# Epoch 164/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0830 - accuracy: 0.5536
# Epoch 165/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0824 - accuracy: 0.5537
# Epoch 166/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0818 - accuracy: 0.5534
# Epoch 167/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0812 - accuracy: 0.5544
# Epoch 168/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0807 - accuracy: 0.5538
# Epoch 169/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0801 - accuracy: 0.5530
# Epoch 170/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0796 - accuracy: 0.5532
# Epoch 171/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0790 - accuracy: 0.5539
# Epoch 172/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.0785 - accuracy: 0.5534
# Epoch 173/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0779 - accuracy: 0.5543
# Epoch 174/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0774 - accuracy: 0.5536
# Epoch 175/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0769 - accuracy: 0.5544
# Epoch 176/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0763 - accuracy: 0.5546
# Epoch 177/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0758 - accuracy: 0.5551
# Epoch 178/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0752 - accuracy: 0.5553
# Epoch 179/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0747 - accuracy: 0.5551
# Epoch 180/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0742 - accuracy: 0.5564
# Epoch 181/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0737 - accuracy: 0.5553
# Epoch 182/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0732 - accuracy: 0.5565
# Epoch 183/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0726 - accuracy: 0.5556
# Epoch 184/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0721 - accuracy: 0.5561
# Epoch 185/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0716 - accuracy: 0.5564
# Epoch 186/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0711 - accuracy: 0.5569
# Epoch 187/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.0706 - accuracy: 0.5572
# Epoch 188/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0701 - accuracy: 0.5584
# Epoch 189/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0696 - accuracy: 0.5576
# Epoch 190/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0691 - accuracy: 0.5586
# Epoch 191/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0686 - accuracy: 0.5593
# Epoch 192/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0681 - accuracy: 0.5593
# Epoch 193/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0676 - accuracy: 0.5586
# Epoch 194/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0672 - accuracy: 0.5594
# Epoch 195/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0667 - accuracy: 0.5586
# Epoch 196/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0662 - accuracy: 0.5585
# Epoch 197/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0657 - accuracy: 0.5600
# Epoch 198/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0652 - accuracy: 0.5591
# Epoch 199/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0648 - accuracy: 0.5612
# Epoch 200/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0643 - accuracy: 0.5603
# Epoch 201/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0638 - accuracy: 0.5598
# Epoch 202/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0634 - accuracy: 0.5598
# Epoch 203/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0629 - accuracy: 0.5600
# Epoch 204/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0624 - accuracy: 0.5610
# Epoch 205/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0620 - accuracy: 0.5609
# Epoch 206/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0615 - accuracy: 0.5610
# Epoch 207/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0611 - accuracy: 0.5610
# Epoch 208/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0606 - accuracy: 0.5609
# Epoch 209/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0602 - accuracy: 0.5616
# Epoch 210/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0597 - accuracy: 0.5624
# Epoch 211/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0593 - accuracy: 0.5619
# Epoch 212/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0588 - accuracy: 0.5620
# Epoch 213/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0584 - accuracy: 0.5630
# Epoch 214/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0579 - accuracy: 0.5626
# Epoch 215/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0575 - accuracy: 0.5630
# Epoch 216/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0571 - accuracy: 0.5634
# Epoch 217/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0566 - accuracy: 0.5625
# Epoch 218/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0562 - accuracy: 0.5633
# Epoch 219/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0558 - accuracy: 0.5630
# Epoch 220/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0553 - accuracy: 0.5633
# Epoch 221/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0549 - accuracy: 0.5635
# Epoch 222/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0545 - accuracy: 0.5639
# Epoch 223/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0541 - accuracy: 0.5648
# Epoch 224/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0536 - accuracy: 0.5647
# Epoch 225/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0532 - accuracy: 0.5649
# Epoch 226/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0528 - accuracy: 0.5654
# Epoch 227/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0524 - accuracy: 0.5648
# Epoch 228/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0520 - accuracy: 0.5653
# Epoch 229/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0516 - accuracy: 0.5650
# Epoch 230/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0512 - accuracy: 0.5656
# Epoch 231/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0508 - accuracy: 0.5650
# Epoch 232/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0504 - accuracy: 0.5662
# Epoch 233/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0500 - accuracy: 0.5662
# Epoch 234/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0496 - accuracy: 0.5652
# Epoch 235/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0492 - accuracy: 0.5660
# Epoch 236/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0488 - accuracy: 0.5661
# Epoch 237/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0484 - accuracy: 0.5654
# Epoch 238/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0480 - accuracy: 0.5658
# Epoch 239/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0476 - accuracy: 0.5661
# Epoch 240/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0472 - accuracy: 0.5656
# Epoch 241/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0468 - accuracy: 0.5658
# Epoch 242/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0464 - accuracy: 0.5669
# Epoch 243/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0460 - accuracy: 0.5667
# Epoch 244/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0456 - accuracy: 0.5670
# Epoch 245/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0453 - accuracy: 0.5661
# Epoch 246/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0449 - accuracy: 0.5669
# Epoch 247/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0445 - accuracy: 0.5670
# Epoch 248/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0441 - accuracy: 0.5660
# Epoch 249/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0437 - accuracy: 0.5680
# Epoch 250/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0434 - accuracy: 0.5673
# Epoch 251/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0430 - accuracy: 0.5685
# Epoch 252/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 1.0426 - accuracy: 0.5660
# Epoch 253/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0423 - accuracy: 0.5678
# Epoch 254/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0419 - accuracy: 0.5684
# Epoch 255/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0415 - accuracy: 0.5685
# Epoch 256/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0412 - accuracy: 0.5684
# Epoch 257/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0408 - accuracy: 0.5682
# Epoch 258/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0404 - accuracy: 0.5690
# Epoch 259/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0401 - accuracy: 0.5678
# Epoch 260/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0397 - accuracy: 0.5674
# Epoch 261/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0393 - accuracy: 0.5688
# Epoch 262/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0390 - accuracy: 0.5684
# Epoch 263/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0386 - accuracy: 0.5684
# Epoch 264/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0383 - accuracy: 0.5691
# Epoch 265/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0379 - accuracy: 0.5700
# Epoch 266/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0376 - accuracy: 0.5696
# Epoch 267/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0372 - accuracy: 0.5700
# Epoch 268/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0369 - accuracy: 0.5685
# Epoch 269/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0365 - accuracy: 0.5703
# Epoch 270/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0362 - accuracy: 0.5699
# Epoch 271/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0358 - accuracy: 0.5703
# Epoch 272/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0355 - accuracy: 0.5703
# Epoch 273/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0352 - accuracy: 0.5694
# Epoch 274/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0348 - accuracy: 0.5697
# Epoch 275/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0345 - accuracy: 0.5705
# Epoch 276/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0341 - accuracy: 0.5710
# Epoch 277/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0338 - accuracy: 0.5701
# Epoch 278/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0335 - accuracy: 0.5711
# Epoch 279/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0331 - accuracy: 0.5699
# Epoch 280/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0328 - accuracy: 0.5720
# Epoch 281/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0325 - accuracy: 0.5706
# Epoch 282/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0321 - accuracy: 0.5714
# Epoch 283/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0318 - accuracy: 0.5704
# Epoch 284/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0315 - accuracy: 0.5708
# Epoch 285/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0312 - accuracy: 0.5715
# Epoch 286/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0308 - accuracy: 0.5721
# Epoch 287/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0305 - accuracy: 0.5715
# Epoch 288/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0302 - accuracy: 0.5722
# Epoch 289/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0299 - accuracy: 0.5716
# Epoch 290/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0296 - accuracy: 0.5721
# Epoch 291/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0292 - accuracy: 0.5720
# Epoch 292/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0289 - accuracy: 0.5720
# Epoch 293/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0286 - accuracy: 0.5730
# Epoch 294/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0283 - accuracy: 0.5728
# Epoch 295/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0280 - accuracy: 0.5723
# Epoch 296/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0277 - accuracy: 0.5727
# Epoch 297/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 1.0273 - accuracy: 0.5727
# Epoch 298/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0270 - accuracy: 0.5727
# Epoch 299/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0267 - accuracy: 0.5723
# Epoch 300/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0264 - accuracy: 0.5737
# Epoch 301/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0261 - accuracy: 0.5740
# Epoch 302/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0258 - accuracy: 0.5732
# Epoch 303/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0255 - accuracy: 0.5738
# Epoch 304/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.0252 - accuracy: 0.5739
# Epoch 305/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0249 - accuracy: 0.5747
# Epoch 306/500
# 10000/10000 [==============================] - 1s 75us/sample - loss: 1.0246 - accuracy: 0.5747
# Epoch 307/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0243 - accuracy: 0.5740
# Epoch 308/500
# 10000/10000 [==============================] - 1s 75us/sample - loss: 1.0240 - accuracy: 0.5743
# Epoch 309/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0237 - accuracy: 0.5736
# Epoch 310/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0234 - accuracy: 0.5747
# Epoch 311/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0231 - accuracy: 0.5743
# Epoch 312/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0228 - accuracy: 0.5750
# Epoch 313/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0225 - accuracy: 0.5750
# Epoch 314/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0222 - accuracy: 0.5745
# Epoch 315/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0219 - accuracy: 0.5754
# Epoch 316/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0216 - accuracy: 0.5746
# Epoch 317/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0213 - accuracy: 0.5739
# Epoch 318/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0210 - accuracy: 0.5748
# Epoch 319/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.0208 - accuracy: 0.5760
# Epoch 320/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0205 - accuracy: 0.5757
# Epoch 321/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0202 - accuracy: 0.5760
# Epoch 322/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0199 - accuracy: 0.5755
# Epoch 323/500
# 10000/10000 [==============================] - 1s 76us/sample - loss: 1.0196 - accuracy: 0.5761
# Epoch 324/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0193 - accuracy: 0.5760
# Epoch 325/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0190 - accuracy: 0.5756
# Epoch 326/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0188 - accuracy: 0.5769
# Epoch 327/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0185 - accuracy: 0.5764
# Epoch 328/500
# 10000/10000 [==============================] - 1s 79us/sample - loss: 1.0182 - accuracy: 0.5765
# Epoch 329/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0179 - accuracy: 0.5766
# Epoch 330/500
# 10000/10000 [==============================] - 1s 77us/sample - loss: 1.0176 - accuracy: 0.5765
# Epoch 331/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0174 - accuracy: 0.5770
# Epoch 332/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0171 - accuracy: 0.5766
# Epoch 333/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0168 - accuracy: 0.5769
# Epoch 334/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0165 - accuracy: 0.5768
# Epoch 335/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0163 - accuracy: 0.5765
# Epoch 336/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0160 - accuracy: 0.5767
# Epoch 337/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0157 - accuracy: 0.5772
# Epoch 338/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0155 - accuracy: 0.5768
# Epoch 339/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 1.0152 - accuracy: 0.5771
# Epoch 340/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0149 - accuracy: 0.5767
# Epoch 341/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0146 - accuracy: 0.5779
# Epoch 342/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0144 - accuracy: 0.5771
# Epoch 343/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0141 - accuracy: 0.5774
# Epoch 344/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0138 - accuracy: 0.5776
# Epoch 345/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0136 - accuracy: 0.5778
# Epoch 346/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0133 - accuracy: 0.5774
# Epoch 347/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0131 - accuracy: 0.5779
# Epoch 348/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0128 - accuracy: 0.5775
# Epoch 349/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0125 - accuracy: 0.5775
# Epoch 350/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0123 - accuracy: 0.5786
# Epoch 351/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 1.0120 - accuracy: 0.5778
# Epoch 352/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0118 - accuracy: 0.5778
# Epoch 353/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0115 - accuracy: 0.5785
# Epoch 354/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0112 - accuracy: 0.5782
# Epoch 355/500
# 10000/10000 [==============================] - 1s 61us/sample - loss: 1.0110 - accuracy: 0.5779
# Epoch 356/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0107 - accuracy: 0.5780
# Epoch 357/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0105 - accuracy: 0.5783
# Epoch 358/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0102 - accuracy: 0.5788
# Epoch 359/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0100 - accuracy: 0.5790
# Epoch 360/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 1.0097 - accuracy: 0.5781
# Epoch 361/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0095 - accuracy: 0.5781
# Epoch 362/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 1.0092 - accuracy: 0.5784
# Epoch 363/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0090 - accuracy: 0.5792
# Epoch 364/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0087 - accuracy: 0.5782
# Epoch 365/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0085 - accuracy: 0.5782
# Epoch 366/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0082 - accuracy: 0.5787
# Epoch 367/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.0080 - accuracy: 0.5787
# Epoch 368/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.0077 - accuracy: 0.5798
# Epoch 369/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0075 - accuracy: 0.5791
# Epoch 370/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0072 - accuracy: 0.5788
# Epoch 371/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.0070 - accuracy: 0.5790
# Epoch 372/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0067 - accuracy: 0.5794
# Epoch 373/500
# ...
# Epoch 192/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5148 - accuracy: 0.8766
# Epoch 193/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5141 - accuracy: 0.8760
# Epoch 194/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.5135 - accuracy: 0.8750
# Epoch 195/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5129 - accuracy: 0.8756
# Epoch 196/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5123 - accuracy: 0.8745
# Epoch 197/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.5117 - accuracy: 0.8758
# Epoch 198/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.5111 - accuracy: 0.8753
# Epoch 199/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.5105 - accuracy: 0.8757
# Epoch 200/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.5099 - accuracy: 0.8760
# Epoch 201/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.5093 - accuracy: 0.8753
# Epoch 202/500
# 10000/10000 [==============================] - 1s 62us/sample - loss: 0.5087 - accuracy: 0.8771
# Epoch 203/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.5081 - accuracy: 0.8760
# Epoch 204/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 0.5075 - accuracy: 0.8771
# Epoch 205/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.5070 - accuracy: 0.8760
# Epoch 206/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.5064 - accuracy: 0.8766
# Epoch 207/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.5058 - accuracy: 0.8769
# Epoch 208/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.5052 - accuracy: 0.8770
# Epoch 209/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5047 - accuracy: 0.8767
# Epoch 210/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.5041 - accuracy: 0.8771
# Epoch 211/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.5036 - accuracy: 0.8763
# Epoch 212/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.5030 - accuracy: 0.8768
# 5000/5000 [==============================] - 0s 73us/sample - loss: 0.5029 - accuracy: 0.8802
#
#
# ==========
# Experiment 2
# Train on 10000 samples
# Epoch 1/500
# 10000/10000 [==============================] - 1s 79us/sample - loss: 1.5326 - accuracy: 0.1424
# Epoch 2/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.4165 - accuracy: 0.2858
# Epoch 3/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.3515 - accuracy: 0.3302
# Epoch 4/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.3010 - accuracy: 0.4082
# Epoch 5/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.2593 - accuracy: 0.4848
# Epoch 6/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.2235 - accuracy: 0.5411
# Epoch 7/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1922 - accuracy: 0.5748
# Epoch 8/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.1642 - accuracy: 0.6828
# Epoch 9/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 1.1390 - accuracy: 0.7445
# Epoch 10/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.1160 - accuracy: 0.7952
# Epoch 11/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 1.0948 - accuracy: 0.8154
# Epoch 12/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0753 - accuracy: 0.8228
# Epoch 13/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 1.0572 - accuracy: 0.8340
# Epoch 14/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 1.0403 - accuracy: 0.8399
# Epoch 15/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.0245 - accuracy: 0.8404
# Epoch 16/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0097 - accuracy: 0.8434
# Epoch 17/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.9957 - accuracy: 0.8441
# Epoch 18/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 0.9825 - accuracy: 0.8493
# Epoch 19/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.9700 - accuracy: 0.8485
# Epoch 20/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.9581 - accuracy: 0.8495
# Epoch 21/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.9468 - accuracy: 0.8497
# Epoch 22/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.9360 - accuracy: 0.8504
# Epoch 23/500
# 10000/10000 [==============================] - 1s 75us/sample - loss: 0.9257 - accuracy: 0.8524
# Epoch 24/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.9159 - accuracy: 0.8558
# Epoch 25/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.9065 - accuracy: 0.8545
# Epoch 26/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.8975 - accuracy: 0.8556
# Epoch 27/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.8888 - accuracy: 0.8534
# Epoch 28/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.8805 - accuracy: 0.8554
# Epoch 29/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8725 - accuracy: 0.8565
# Epoch 30/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8648 - accuracy: 0.8581
# Epoch 31/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.8574 - accuracy: 0.8558
# Epoch 32/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.8502 - accuracy: 0.8609
# Epoch 33/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8433 - accuracy: 0.8586
# Epoch 34/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.8366 - accuracy: 0.8610
# Epoch 35/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.8301 - accuracy: 0.8600
# Epoch 36/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8239 - accuracy: 0.8608
# Epoch 37/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.8178 - accuracy: 0.8605
# Epoch 38/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8120 - accuracy: 0.8592
# Epoch 39/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8063 - accuracy: 0.8632
# Epoch 40/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.8007 - accuracy: 0.8628
# Epoch 41/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.7954 - accuracy: 0.8611
# Epoch 42/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7902 - accuracy: 0.8612
# Epoch 43/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.7851 - accuracy: 0.8625
# Epoch 44/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.7802 - accuracy: 0.8628
# Epoch 45/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.7754 - accuracy: 0.8632
# Epoch 46/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.7707 - accuracy: 0.8645
# Epoch 47/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.7661 - accuracy: 0.8642
# Epoch 48/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.7617 - accuracy: 0.8665
# Epoch 49/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7574 - accuracy: 0.8659
# Epoch 50/500
# 10000/10000 [==============================] - 1s 75us/sample - loss: 0.7531 - accuracy: 0.8668
# Epoch 51/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7490 - accuracy: 0.8656
# Epoch 52/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.7450 - accuracy: 0.8669
# Epoch 53/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.7411 - accuracy: 0.8665
# Epoch 54/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.7372 - accuracy: 0.8679
# Epoch 55/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7335 - accuracy: 0.8691
# Epoch 56/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.7298 - accuracy: 0.8677
# Epoch 57/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.7262 - accuracy: 0.8675
# Epoch 58/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 0.7227 - accuracy: 0.8681
# Epoch 59/500
# 10000/10000 [==============================] - 1s 63us/sample - loss: 0.7193 - accuracy: 0.8666
# Epoch 60/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.7159 - accuracy: 0.8688
# Epoch 61/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7126 - accuracy: 0.8673
# Epoch 62/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.7094 - accuracy: 0.8687
# Epoch 63/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.7062 - accuracy: 0.8685
# Epoch 64/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.7031 - accuracy: 0.8692
# Epoch 65/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.7001 - accuracy: 0.8686
# Epoch 66/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.6971 - accuracy: 0.8703
# Epoch 67/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.6942 - accuracy: 0.8710
# Epoch 68/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.6913 - accuracy: 0.8720
# Epoch 69/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.6885 - accuracy: 0.8692
# Epoch 70/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.6858 - accuracy: 0.8691
# Epoch 71/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.6831 - accuracy: 0.8722
# Epoch 72/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.6804 - accuracy: 0.8700
# Epoch 73/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.6778 - accuracy: 0.8738
# Epoch 74/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.6752 - accuracy: 0.8720
# Epoch 75/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.6727 - accuracy: 0.8720
# Epoch 76/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.6702 - accuracy: 0.8728
# Epoch 77/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.6678 - accuracy: 0.8713
# Epoch 78/500
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.6654 - accuracy: 0.8721
# Epoch 79/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.6630 - accuracy: 0.8720
# Epoch 80/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.6607 - accuracy: 0.8737
# Epoch 81/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.6584 - accuracy: 0.8734
# Epoch 82/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 0.6562 - accuracy: 0.8725
# Epoch 83/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.6540 - accuracy: 0.8738
# 5000/5000 [==============================] - 0s 71us/sample - loss: 0.6532 - accuracy: 0.8768
#
#
# ==========
# Experiment 3
# Train on 10000 samples
# Epoch 1/500
# 10000/10000 [==============================] - 1s 87us/sample - loss: 1.3206 - accuracy: 0.4903
# Epoch 2/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 1.2277 - accuracy: 0.6522
# Epoch 3/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 1.1731 - accuracy: 0.7044
# Epoch 4/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 1.1316 - accuracy: 0.7491
# Epoch 5/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 1.0977 - accuracy: 0.7795
# Epoch 6/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0690 - accuracy: 0.8109
# Epoch 7/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 1.0440 - accuracy: 0.8178
# Epoch 8/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 1.0218 - accuracy: 0.8270
# Epoch 9/500
# 10000/10000 [==============================] - 1s 78us/sample - loss: 1.0019 - accuracy: 0.8370
# Epoch 10/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.9838 - accuracy: 0.8375
# Epoch 11/500
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.9671 - accuracy: 0.8434
# Epoch 12/500
# 10000/10000 [==============================] - 1s 76us/sample - loss: 0.9518 - accuracy: 0.8379
# Epoch 13/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.9376 - accuracy: 0.8434
# Epoch 14/500
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.9244 - accuracy: 0.8432
# Epoch 15/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.9120 - accuracy: 0.8428
# Epoch 16/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.9004 - accuracy: 0.8448
# Epoch 17/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.8894 - accuracy: 0.8441
# Epoch 18/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8791 - accuracy: 0.8481
# Epoch 19/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.8692 - accuracy: 0.8466
# Epoch 20/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8599 - accuracy: 0.8482
# Epoch 21/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8511 - accuracy: 0.8488
# Epoch 22/500
# 10000/10000 [==============================] - 1s 70us/sample - loss: 0.8426 - accuracy: 0.8500
# Epoch 23/500
# 10000/10000 [==============================] - 1s 69us/sample - loss: 0.8345 - accuracy: 0.8538
# Epoch 24/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.8268 - accuracy: 0.8556
# Epoch 25/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.8194 - accuracy: 0.8525
# Epoch 26/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.8123 - accuracy: 0.8567
# Epoch 27/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.8054 - accuracy: 0.8507
# Epoch 28/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7989 - accuracy: 0.8529
# Epoch 29/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7926 - accuracy: 0.8549
# Epoch 30/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.7865 - accuracy: 0.8583
# Epoch 31/500
# 10000/10000 [==============================] - 1s 72us/sample - loss: 0.7806 - accuracy: 0.8554
# Epoch 32/500
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.7749 - accuracy: 0.8621
# Epoch 33/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7694 - accuracy: 0.8575
# Epoch 34/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7641 - accuracy: 0.8626
# Epoch 35/500
# 10000/10000 [==============================] - 1s 73us/sample - loss: 0.7590 - accuracy: 0.8593
# Epoch 36/500
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.7540 - accuracy: 0.8606
# Epoch 37/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7492 - accuracy: 0.8613
# Epoch 38/500
# 10000/10000 [==============================] - 1s 71us/sample - loss: 0.7445 - accuracy: 0.8581
# Epoch 39/500
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.7400 - accuracy: 0.8629
# Buffered data was truncated after reaching the output size limit.

# %% [markdown]
# # Qualitative measure
#
# In this section, the models are evaluated qualitativevly by observing the changes in latent activations ($z_i$) as we fix all but one generative latent factor. If the model disentangles generative factors well, the latent activation should be sensitive to (and only to) the corresponding fixed latent factor.

# %%
SAMPLE_SIZE = 500
sample_latents = ds.sample_latent(SAMPLE_SIZE)

def pos_latent_heatmap(model, sample_latents, dim):
    lats = sample_latents.copy()
    heatmap = np.full(
        (ds.latent_size(DSprites.Latents.YPOS),
         ds.latent_size(DSprites.Latents.XPOS)),
        0, dtype=np.float32
    )
    for x in range(ds.latent_size(DSprites.Latents.XPOS)):
        lats[:, DSprites.Latents.XPOS] = x
        for y in range(ds.latent_size(DSprites.Latents.YPOS)):
            lats[:, DSprites.Latents.YPOS] = y
            z, mean, logvar = model.encode(ds.imgs[ds.to_idx(lats)])
            z = z.numpy()
            # notice how it's [y, x] since the rows represent the y-axis
            heatmap[y, x] = np.mean(z[:, dim])
    return heatmap

def latent_activations(latent: DSprites.Latents, model, sample_latents, dim):
    lats = sample_latents.copy()
    square_idxs = lats[:, DSprites.Latents.SHAPE] == 0
    oval_idxs = lats[:, DSprites.Latents.SHAPE] == 1
    heart_idxs = lats[:, DSprites.Latents.SHAPE] == 2
    assert (square_idxs | oval_idxs | heart_idxs).all()
    scales = {'square': [], 'oval': [], 'heart': []}
    for l in range(ds.latent_size(latent)):
        lats[:, latent] = l
        z, mean, logvar = model.encode(ds.imgs[ds.to_idx(lats)])
        z = z.numpy()
        scales['square'].append(np.mean(z[square_idxs, dim]))
        scales['oval'].append(np.mean(z[oval_idxs, dim]))
        scales['heart'].append(np.mean(z[heart_idxs, dim]))
    return scales

def latent_shape_activations(model, sample_latents, dim):
    lats = sample_latents.copy()
    shapes = [[], [], []]
    for l in range(ds.latent_size(DSprites.Latents.SHAPE)):
        lats[:, DSprites.Latents.SHAPE] = l
        z, mean, logvar = model.encode(ds.imgs[ds.to_idx(lats)])
        z = z.numpy()
        shapes[l] = z[:, dim]
    return {'square': shapes[0], 'oval': shapes[1], 'heart': shapes[2]}


def vary_latent(seed_img, model: VAE, dim: int,
                zmin: float=-2, zmax: float=2, step: float=1,
                activation: typing.Callable[[tf.Tensor], tf.Tensor]=None) -> np.array:
    """
    :param seed_img: image used as seed when varying latents. This image
                     will be encoded by `model.encode(seed_img)` and the
                     resulting `z` latent vector will be varied. Should be
                     of shape (B, W, H, C).
    :param model: VAE model used to encode and decode latents                     
    :param dim: the dimension to vary. This value must be 0 <= dim < LATENT_DIM
    :param zmin: determines the range of `z` to vary. `z` is varied starting from
    `z[dim] + zmin` to `z[dim] + zmax`. Must be a negative value.
    :param zmax: determines the range of `z` to vary. `z` is varied starting from
    `z[dim] + zmin` to `z[dim] + zmax`. Must be a positive value.
    :param step: the step size used to increment `z` when varying `z[dim]`.
    :param activation: activation function to apply on
                       `activation(model.decode(z))`. None applied if `None`
                       (default).
    :return: a numpy array of shape (N, B, W, H, C) where:
              - N: number of total images generated when varying `z` according
                   to `zmin`, `zmax`, `step`.
                   That is, N = 1 + abs(zmax - zmin) // step
              - B: batch size. This is the same as `seed_img.shape[0]`
              - W: image width. This is the same as `seed_img.shape[1]`
              - H: image height. This is the same as `seed_img.shape[2]`
              - C: image channel. This is the same as `seed_img.shape[3]`
    """
    assert zmin < 0 and zmax > 0
    if not activation:
        activation = lambda x: x
    z, *_ = model.encode(seed_img)
    z = z.numpy()
    z[:, dim] += zmin
    reconstructed = []
    reconstructed.append(activation(model.decode(z)))
    for _ in range(int(abs(zmax - zmin) // step)):
        z[:, dim] += step
        reconstructed.append(activation(model.decode(z)))
    reconstructed = np.flip(np.array(reconstructed), axis=0)
    return reconstructed

def show_latents(model, dims: list, ds: DSprites,
                 reconstruction_activation_function: typing.Callable[[tf.Tensor], tf.Tensor]=None,
                 save: typing.Optional[str]=None):
    """
    Plots figure 7 in Higgins et al. (2017)

    :param model: Any model that has the `encode` and `decode` functions.
            `encode` is required to return a 3-tuple
            (z, _, _) where z is the latent vector.
    :param dims: List of dimensions to visualise.
    :param ds: DSprites dataset
    :param reconstruction_activation_function: Activation function to apply on
                                               `activation(model.decode(z))`.
                                               None applied if `None` (default).

    :param save: If not none, save to path indicated.
    """
    nrows = 9
    ncols = 5
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 18))
    ax = ax.flatten()
    for i, dim in enumerate(dims):
        ax[i].imshow(pos_latent_heatmap(model, sample_latents, dim=dim),
                     cmap='RdBu_r', interpolation='bilinear')
        ax[i].set_title(f"$z_{dim}$")
        ax[i].title.set_fontsize(15)
        ax[i].set_xticks(())
        ax[i].set_yticks(())
        if i % ncols == 0:
            ax[i].set_ylabel("position")
            ax[i].yaxis.label.set_fontsize(15)
        
    for i, dim in enumerate(dims, i + 1):
        scale = latent_activations(DSprites.Latents.SCALE, model,
                                   sample_latents, dim=dim)
        ax[i].plot(scale['oval'], color='green')
        ax[i].plot(scale['heart'], color='blue')
        ax[i].plot(scale['square'], color='red')
        ax[i].set_xticks(())
        ax[i].set_yticks(())
        if i % ncols == 0:
            ax[i].set_ylabel("scale")
            ax[i].yaxis.label.set_fontsize(15)
    
    for i, dim in enumerate(dims, i + 1):
        scale = latent_activations(DSprites.Latents.ORIENTATION,
                                   model, sample_latents, dim=dim)
        ax[i].plot(scale['oval'], color='green')
        ax[i].plot(scale['heart'], color='blue')
        ax[i].plot(scale['square'], color='red')
        ax[i].set_xticks(())
        ax[i].set_yticks(())
        if i % ncols == 0:
            ax[i].set_ylabel("rotation")
            ax[i].yaxis.label.set_fontsize(15)

    def draw_whisker(ax, data, colour):
        p = ax.boxplot(data, patch_artist=True, showfliers=False)
        for i, patch in enumerate(p['boxes']):
            patch.set(facecolor='white', edgecolor=colour[i])

    for i, dim in enumerate(dims, i + 1):
        shape = latent_shape_activations(model, sample_latents, dim=dim)
        draw_whisker(ax[i], [shape['oval'], shape['heart'], shape['square']],
                     colour=['green', 'blue', 'red'])
        ax[i].set_xticks(())
        ax[i].set_yticks(())
        if i % ncols == 0:
            ax[i].set_ylabel("shape")
            ax[i].yaxis.label.set_fontsize(15)

    seed_img = ds.sample_latent(1)
    # show ovals
    seed_img[:, DSprites.Latents.SHAPE] = 1
    seed_img = ds.imgs[ds.to_idx(seed_img)]
    for i, dim in enumerate(dims, i + 1):
        # we're only varying the latent of one seed_img, squeeze axis=1
        # to get shape (N, W, H, C) where N = num images generated by varying
        # latents, W = width, H = height, C = channels
        recon =  vary_latent(seed_img, model, dim=dim,
                             activation=reconstruction_activation_function).squeeze(axis=1)
        for j in range(recon.shape[0]):
            ax[i + j * 5].imshow(recon[j].squeeze(), cmap='gray', interpolation='nearest')
            ax[i + j * 5].set_xticks(())
            ax[i + j * 5].set_yticks(())

    fig.subplots_adjust(wspace=0.1, hspace=0.1)
    square_patch = mpatches.Patch(color='red', label='Square')
    heart_patch = mpatches.Patch(color='blue', label='Heart')
    oval_patch = mpatches.Patch(color='green', label='Oval')
    plt.legend(handles=[square_patch, heart_patch, oval_patch], loc='lower center',
               bbox_to_anchor=(-0.1, -0.35), ncol=3)
    if save: plt.savefig(save)

# %%
# show_latents(vae4, dims=[9, 8, 0, 5, 6], ds=ds, reconstruction_activation_function=tf.nn.sigmoid, save="beta4.png")

# %%
# show_latents(vae1, dims=[0, 4, 6, 8, 9], ds=ds, reconstruction_activation_function=tf.nn.sigmoid, save="beta1.png")

# %%
np.save("beta_accs.npy", accs)

# %%
# plot 2-stddev to show 95% confidence
fig = plt.figure(num=1, figsize=(8, 8))
_, caps, _ = plt.errorbar(x=([0.5] + list(range(1, 11))),
                          y=np.mean(accs, axis=1), yerr=(np.std(accs, axis=1)*2),
                          fmt='o', markersize=5, capsize=10)
for cap in caps:
    cap.set_markeredgewidth(1)

plt.xticks([0.5] + list(range(1, 11)))
plt.xlabel(r"$\beta$")
plt.ylabel(r"$\beta$-VAE disentanglement metric");
plt.grid()
plt.savefig("beta_search.png")
